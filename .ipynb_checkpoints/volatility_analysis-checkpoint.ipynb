# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-1.2.0-py2.py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pandas>=1.3.0 in C:\Users\shrey\AppData\Local\Programs\Python\Python311\Lib\site-packages (from yfinance) (2.1.1)
# Requirement already satisfied: numpy>=1.16.5 in C:\Users\shrey\AppData\Local\Programs\Python\Python311\Lib\site-packages (from yfinance) (1.26.0)
# Requirement already satisfied: requests>=2.31 in C:\Users\shrey\AppData\Local\Programs\Python\Python311\Lib\site-packages (from yfinance) (2.32.3)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.12.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: platformdirs>=2.0.0 in C:\Users\shrey\AppData\Local\Programs\Python\Python311\Lib\site-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in C:\Users\shrey\AppData\Local\Programs\Python\Python311\Lib\site-packages (from yfinance) (2023.3.post1)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.7-py3-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-4.0.2-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in C:\Users\shrey\AppData\Local\Programs\Python\Python311\Lib\site-packages (from yfinance) (4.13.3)
# Collecting curl_cffi<0.14,>=0.7 (from yfinance)
#   Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl.metadata (13 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Downloading protobuf-7.34.0-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Requirement already satisfied: websockets>=13.0 in C:\Users\shrey\AppData\Local\Programs\Python\Python311\Lib\site-packages (from yfinance) (14.2)
# Requirement already satisfied: cffi>=1.12.0 in C:\Users\shrey\AppData\Local\Programs\Python\Python311\Lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in C:\Users\shrey\AppData\Local\Programs\Python\Python311\Lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in C:\Users\shrey\AppData\Local\Programs\Python\Python311\Lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\shrey\AppData\Local\Programs\Python\Python311\Lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Requirement already satisfied: pycparser in C:\Users\shrey\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\shrey\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in C:\Users\shrey\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: six>=1.5 in C:\Users\shrey\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in C:\Users\shrey\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\shrey\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\shrey\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Downloading yfinance-1.2.0-py2.py3-none-any.whl (130 kB)
# Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    -------------------------------------- - 1.6/1.6 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 7.2 MB/s  0:00:00
# Downloading frozendict-2.4.7-py3-none-any.whl (16 kB)
# Downloading peewee-4.0.2-py3-none-any.whl (143 kB)
# Downloading protobuf-7.34.0-cp310-abi3-win_amd64.whl (437 kB)
# Building wheels for collected packages: multitasking
#   Building wheel for multitasking (pyproject.toml): started
#   Building wheel for multitasking (pyproject.toml): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15702 sha256=c7f9dc85acb6c0082ee828a162edb60492b57ac8b4e5b7bc4a3d5ccc46817dc6
#   Stored in directory: c:\users\shrey\appdata\local\pip\cache\wheels\42\d6\84\bf57a755f4569494cd00de4bb46ef064874823f4d19c82e960
# Successfully built multitasking
# Installing collected packages: peewee, multitasking, protobuf, frozendict, curl_cffi, yfinance
#
#    ---------------------------------------- 0/6 [peewee]
#    ---------------------------------------- 0/6 [peewee]
#    ---------------------------------------- 0/6 [peewee]
#    ---------------------------------------- 0/6 [peewee]
#    ---------------------------------------- 0/6 [peewee]
#    ---------------------------------------- 0/6 [peewee]
#    ---------------------------------------- 0/6 [peewee]
#    ---------------------------------------- 0/6 [peewee]
#    ---------------------------------------- 0/6 [peewee]
#    ------ --------------------------------- 1/6 [multitasking]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    -------------------- ------------------- 3/6 [frozendict]
#    -------------------------- ------------- 4/6 [curl_cffi]
#    -------------------------- ------------- 4/6 [curl_cffi]
#    -------------------------- ------------- 4/6 [curl_cffi]
#    -------------------------- ------------- 4/6 [curl_cffi]
#    -------------------------- ------------- 4/6 [curl_cffi]
#    --------------------------------- ------ 5/6 [yfinance]
#    --------------------------------- ------ 5/6 [yfinance]
#    --------------------------------- ------ 5/6 [yfinance]
#    --------------------------------- ------ 5/6 [yfinance]
#    --------------------------------- ------ 5/6 [yfinance]
#    --------------------------------- ------ 5/6 [yfinance]
#    --------------------------------- ------ 5/6 [yfinance]
#    --------------------------------- ------ 5/6 [yfinance]
#    --------------------------------- ------ 5/6 [yfinance]
#    --------------------------------- ------ 5/6 [yfinance]
#    --------------------------------- ------ 5/6 [yfinance]
#    --------------------------------- ------ 5/6 [yfinance]
#    --------------------------------- ------ 5/6 [yfinance]
#    ---------------------------------------- 6/6 [yfinance]
#
# Successfully installed curl_cffi-0.13.0 frozendict-2.4.7 multitasking-0.0.12 peewee-4.0.2 protobuf-7.34.0 yfinance-1.2.0
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in C:\Users\shrey\AppData\Local\Programs\Python\Python311\Lib\site-packages (26.0)
# Collecting pip
#   Downloading pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-26.0.1-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------------- ---------------- 1.0/1.8 MB 12.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 9.8 MB/s  0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 26.0
#     Uninstalling pip-26.0:
#       Successfully uninstalled pip-26.0
# Successfully installed pip-26.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# %%
data = yf.download("AAPL", start="2022-01-01", end="2026-01-01")
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2022-01-03  178.103668  178.955006  173.895967  174.013387  104487900
# 2022-01-04  175.843262  179.013730  175.275708  178.710386   99310400
# 2022-01-05  171.165848  176.303172  170.891858  175.755193   94537600
# 2022-01-06  168.308517  171.537695  167.956243  168.993491   96904000
# 2022-01-07  168.474838  170.402559  167.359306  169.179387   86709100

# %%
data['log_return'] = np.log(data['Close'] / data['Close'].shift(1))
data['RV'] = data['log_return'] ** 2

# %%
plt.figure()
plt.plot(data['RV'])
plt.title("Realized Volatility (Squared Returns)")
plt.show()

# %%
data['RV_t+1'] = data['RV'].shift(-1)
data['baseline_pred'] = data['RV']
